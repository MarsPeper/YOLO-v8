# %% [markdown]
# # AI537 HW 3: Cat, Dog, and Monkey Detection with YOLOv8
#
# Object detection refers to the task where given a picture, the goal is for a network to predict all the categories of objects included in the picture and their corresponding bounding boxes.
#
# <div align=center>
# <img src="https://user-images.githubusercontent.com/17425982/220232979-fffa480b-9ae6-4601-8af6-4116265dc650.png" alt="object detection" width="800"/>
# </div>
#
# In this project, we will train/test a YOLOv8 object detector on a small cat/dog/monkey dataset. The whole process consists of the following steps:
#
# - [Installation and Setup](#installation-and-setup)
# - [Dataset](#dataset)
# - [Config](#config)
# - [Training](#training)
# - [Testing](#testing)

# %% [markdown]
# ## Installation and Setup
#
# Please refer to the `README_AI537.md` for detailed installation and environment setup instructions.
#
# After installation/setup is complete, the next two cells can be run as a sanity check to ensure certain parts of the environment are setup correctly.

# %%
# check 
# !python -V
# Check nvcc version
# !nvcc -V
# Check GCC version
# !gcc --version
# Check GPU
# !nvidia-smi
# Out:
# Python 3.8.19
# /bin/bash: line 1: nvcc: command not found
# gcc (GCC) 11.4.1 20230605 (Red Hat 11.4.1-2)
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Sun Jun  9 16:53:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A40                     On  | 00000000:25:00.0 Off |                    0 |
# |  0%   24C    P8              21W / 300W |     33MiB / 46068MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     89155      G   /usr/libexec/Xorg                            10MiB |
# |    0   N/A  N/A     89162      G   /usr/libexec/Xorg                             4MiB |
# +---------------------------------------------------------------------------------------+

# %%
# Check PyTorch version
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.0.1+cu118
# True

# %% [markdown]
# ## Dataset
#
# The cat_dog_monkey dataset is a three-category dataset consisting of 438/51/31 images in the training/validation/testing splits. The original dataset is from
# [Monkey, Cat and Dog detection](https://www.kaggle.com/datasets/tarunbisht11/yolo-animal-detection-small).
#
# <div align=center style="display: flex; flex-direction: column;">
#     <figure>
#         <img src="example_imgs/cats_and_monkeys_009.jpg" alt="Image 1" style="height: 200px; width: auto; margin-bottom: 5px;">
#         <figcaption style="text-align: center;">Monkey and cat</figcaption>
#     </figure>
#     <figure>
#         <img src="example_imgs/dogs_and_cats_000.jpg" alt="Image 2" style="height: 200px; width: auto; margin-bottom: 5px;">
#         <figcaption style="text-align: center;">Dog and cat</figcaption>
#     </figure>
# </div>
#
#
#
# We have done some additional processing to the dataset for generating bounding box annotations in the COCO format as well as generating several different annotation files to be used for training. Please download the processed dataset from Canvas, and place the downloaded ```cat_dog_monkey_dataset/``` directory into the ```data/``` directory of the ```mmyolo_AI537_2024Spring``` project.
#
# If done correctly, data should be structured as follows:
# ```text
# - mmyolo_AI537_2024Spring/
#     - data/
#         - cat_dog_monkey_dataset/
#             - train/
#                 - cats_001.jpg
#                 - cats_002.jpg
#                 ...
#             - val/
#                 - cats_000.jpg
#                 - cats_007.jpg
#                 ...
#             - train_cat_annotation_100.json
#             - train_cat_annotation_50.json
#             - train_cat_annotation_20.json
#             - train_cat_annotation_5.json
#             - train_cat_annotation_0.json
#             - val.json
# ```
#
# The contents of the dataset are:
# - The `data/cat_dog_monkey_dataset/train/` and `data/cat_dog_monkey_dataset/val/` directories store all the images.
# - The `data/cat_dog_monkey_dataset/train_cat_annotation_*.json` and `data/cat_dog_monkey_dataset/val.json` files store annotations in COCO format.

# %% [markdown]
# ## Config
# In this project, you will train several YOLOv8 models on training datasets with various amount of ground truth annotations for cats. For each of the ground truth annotation files/datasets, the goal is to find the best model performance across the three classes (cat, dog, and monkey) on the validation dataset. You will also be exploring how performance is impacted when you have different amounts of ground truth cat annotations to use for training a model in a supervised learning setting.
#
# Completing this assignment will require you to train your model with the different ground truth annotation files and to try out different combinations of loss functions common to object detection. To help with this, we have provided you a config file called `ai537_yolov8_config.py` located in the `configs/yolov8/` directory. All changes with regards to model training will only need to be made in this file.
#
# Comments have been added throughout the config file outlining the major settings you are expected to play around with for this assignment. Please also refer to the `README_AI537.md` for full details on what parts of the config are expected to be changed for this assignment.

# %% [markdown]
# ## Training
# You will be training your model on various different annotated datasets. Specifying which dataset and which losses (and their loss weights) are being used should all be done in our config file `configs/yolov8/ai537_yolov8_config.py` (refer to `README_AI537.md`).
#
# Once you have setup the config file, you will simply run the command below to train your model. Training each model should be relatively fast. For example, training for 20 epochs on a NVIDIA RTX 4090 GPU takes less than two minutes.
#
# At the end of training, the performance on the validation set should be printed as follows:
#
# ```text
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.677
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.863
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.581
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.738
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.414
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.749
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.716
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.824
# ```
#
# The above properties are printed via the COCO API. According to the rules defined by COCO, the cat_dog_monkey dataset contains small, median and large-sized objects. For this assignment, __AP@50__ and __AP@75__ are the most important metrics to evaluate your model performance against. The results shown at the ending of training are the mean AP (the average across all classes). To get the per class AP, see the [Testing](#Testing) section.
#
# To train your model, run the following:

# %%
# !python tools/train.py configs/yolov8/ai537_yolov8_config.py
# Out:
# 06/09 16:53:52 - mmengine - WARNING - Failed to search registry with scope "mmyolo" in the "log_processor" registry tree. As a workaround, the current "log_processor" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmyolo" is a correct scope, or whether the registry is initialized.
# 06/09 16:53:53 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.19 (default, Mar 20 2024, 19:58:24) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 52796032
#     GPU 0: NVIDIA A40
#     CUDA_HOME: None
#     GCC: gcc (GCC) 11.4.1 20230605 (Red Hat 11.4.1-2)
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.9.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 52796032
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/09 16:53:54 - mmengine - INFO - Config:
# _backend_args = None
# _multiscale_resize_transforms = [
#     dict(
#         transforms=[
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
#     dict(
#         transforms=[
#             dict(scale=(
#                 320,
#                 320,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     320,
#                     320,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
#     dict(
#         transforms=[
#             dict(scale=(
#                 960,
#                 960,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     960,
#                     960,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
# ]
# affine_scale = 0.5
# albu_train_transforms = [
#     dict(p=0.01, type='Blur'),
#     dict(p=0.01, type='MedianBlur'),
#     dict(p=0.01, type='ToGray'),
#     dict(p=0.01, type='CLAHE'),
# ]
# backend_args = None
# base_lr = 0.01
# batch_shapes_cfg = None
# class_name = (
#     'cat',
#     'dog',
#     'monkey',
# )
# close_mosaic_epochs = 5
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0001,
#         priority=49,
#         strict_load=False,
#         type='EMAHook',
#         update_buffers=True),
#     dict(
#         switch_epoch=95,
#         switch_pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=True,
#                 pad_val=dict(img=114.0),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_aspect_ratio=100,
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='mmdet.PipelineSwitchHook'),
# ]
# data_root = './data/cat_dog_monkey_dataset/'
# dataset_type = 'YOLOv5CocoDataset'
# deepen_factor = 0.33
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=2, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=5, type='LoggerHook'),
#     param_scheduler=dict(
#         lr_factor=0.01,
#         max_epochs=100,
#         scheduler_type='linear',
#         type='YOLOv5ParamSchedulerHook',
#         warmup_mim_iter=10),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='mmdet.DetVisualizationHook'))
# default_scope = 'mmyolo'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_scale = (
#     640,
#     640,
# )
# img_scales = [
#     (
#         640,
#         640,
#     ),
#     (
#         320,
#         320,
#     ),
#     (
#         960,
#         960,
#     ),
# ]
# last_stage_out_channels = 1024
# last_transform = [
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# launcher = 'none'
# load_from = 'https://download.openmmlab.com/mmyolo/v0/yolov8/yolov8_s_syncbn_fast_8xb16-500e_coco/yolov8_s_syncbn_fast_8xb16-500e_coco_20230117_180101-5aa5f0f1.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 8.5
# loss_cls_weight = 1.0
# loss_dfl_weight = 0.275
# lr_factor = 0.01
# max_aspect_ratio = 100
# max_epochs = 100
# max_keep_ckpts = 2
# metainfo = dict(
#     classes=(
#         'cat',
#         'dog',
#         'monkey',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#         (
#             119,
#             11,
#             32,
#         ),
#         (
#             165,
#             42,
#             42,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         arch='P5',
#         deepen_factor=0.33,
#         frozen_stages=4,
#         last_stage_out_channels=1024,
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         type='YOLOv8CSPDarknet',
#         widen_factor=0.5),
#     bbox_head=dict(
#         bbox_coder=dict(type='DistancePointBBoxCoder'),
#         head_module=dict(
#             act_cfg=dict(inplace=True, type='SiLU'),
#             featmap_strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             in_channels=[
#                 256,
#                 512,
#                 1024,
#             ],
#             norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#             num_classes=3,
#             reg_max=16,
#             type='YOLOv8HeadModule',
#             widen_factor=0.5),
#         loss_bbox=dict(
#             bbox_format='xyxy',
#             iou_mode='ciou',
#             loss_weight=8.5,
#             reduction='sum',
#             return_iou=False,
#             type='IoULoss'),
#         loss_cls=dict(
#             alpha=0.25,
#             gamma=2.0,
#             loss_weight=1.0,
#             reduction='none',
#             type='mmdet.FocalLoss',
#             use_sigmoid=True),
#         loss_dfl=dict(
#             loss_weight=0.275,
#             reduction='mean',
#             type='mmdet.DistributionFocalLoss'),
#         prior_generator=dict(
#             offset=0.5, strides=[
#                 8,
#                 16,
#                 32,
#             ], type='mmdet.MlvlPointGenerator'),
#         type='YOLOv8Head'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             0.0,
#             0.0,
#             0.0,
#         ],
#         std=[
#             255.0,
#             255.0,
#             255.0,
#         ],
#         type='YOLOv5DetDataPreprocessor'),
#     neck=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         deepen_factor=0.33,
#         in_channels=[
#             256,
#             512,
#             1024,
#         ],
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         num_csp_blocks=3,
#         out_channels=[
#             256,
#             512,
#             1024,
#         ],
#         type='YOLOv8PAFPN',
#         widen_factor=0.5),
#     test_cfg=dict(
#         max_per_img=300,
#         multi_label=True,
#         nms=dict(iou_threshold=0.7, type='nms'),
#         nms_pre=30000,
#         score_thr=0.001),
#     train_cfg=dict(
#         assigner=dict(
#             alpha=0.5,
#             beta=6.0,
#             eps=1e-09,
#             num_classes=3,
#             topk=10,
#             type='BatchTaskAlignedAssigner',
#             use_ciou=True)),
#     type='YOLODetector')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.7, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# norm_cfg = dict(eps=0.001, momentum=0.03, type='BN')
# num_classes = 3
# num_det_layers = 3
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=10.0),
#     constructor='YOLOv5OptimizerConstructor',
#     optimizer=dict(
#         batch_size_per_gpu=8,
#         lr=0.01,
#         momentum=0.937,
#         nesterov=True,
#         type='SGD',
#         weight_decay=0.0005),
#     type='OptimWrapper')
# param_scheduler = None
# persistent_workers = True
# pre_transform = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
# ]
# resume = False
# save_epoch_intervals = 10
# strides = [
#     8,
#     16,
#     32,
# ]
# tal_alpha = 0.5
# tal_beta = 6.0
# tal_topk = 10
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img='val/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='YOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='./data/cat_dog_monkey_dataset/val.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(scale=(
#         640,
#         640,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=False,
#         pad_val=dict(img=114),
#         scale=(
#             640,
#             640,
#         ),
#         type='LetterResize'),
#     dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'pad_param',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_ann_file = 'annotations/instances_train2017.json'
# train_batch_size_per_gpu = 8
# train_cfg = dict(
#     dynamic_intervals=[
#         (
#             490,
#             1,
#         ),
#     ],
#     max_epochs=100,
#     type='EpochBasedTrainLoop',
#     val_interval=10)
# train_data_prefix = 'train2017/'
# train_dataloader = dict(
#     batch_size=8,
#     collate_fn=dict(type='yolov5_collate'),
#     dataset=dict(
#         ann_file='train_cat_annotation_100.json',
#         data_prefix=dict(img='train/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 img_scale=(
#                     640,
#                     640,
#                 ),
#                 pad_val=114.0,
#                 pre_transform=[
#                     dict(backend_args=None, type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                 ],
#                 type='Mosaic'),
#             dict(
#                 border=(
#                     -320,
#                     -320,
#                 ),
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_aspect_ratio=100,
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='YOLOv5CocoDataset'),
#     num_workers=1,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_num_workers = 1
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         img_scale=(
#             640,
#             640,
#         ),
#         pad_val=114.0,
#         pre_transform=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#         ],
#         type='Mosaic'),
#     dict(
#         border=(
#             -320,
#             -320,
#         ),
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_pipeline_stage2 = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(scale=(
#         640,
#         640,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=True,
#         pad_val=dict(img=114.0),
#         scale=(
#             640,
#             640,
#         ),
#         type='LetterResize'),
#     dict(
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# tta_model = dict(
#     tta_cfg=dict(max_per_img=300, nms=dict(iou_threshold=0.65, type='nms')),
#     type='mmdet.DetTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             640,
#                             640,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 640,
#                                 640,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             320,
#                             320,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 320,
#                                 320,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             960,
#                             960,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 960,
#                                 960,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#             ],
#             [
#                 dict(prob=1.0, type='mmdet.RandomFlip'),
#                 dict(prob=0.0, type='mmdet.RandomFlip'),
#             ],
#             [
#                 dict(type='mmdet.LoadAnnotations', with_bbox=True),
#             ],
#             [
#                 dict(
#                     meta_keys=(
#                         'img_id',
#                         'img_path',
#                         'ori_shape',
#                         'img_shape',
#                         'scale_factor',
#                         'pad_param',
#                         'flip',
#                         'flip_direction',
#                     ),
#                     type='mmdet.PackDetInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_ann_file = 'annotations/instances_val2017.json'
# val_batch_size_per_gpu = 1
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'val2017/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img='val/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='YOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='./data/cat_dog_monkey_dataset/val.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 2
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='mmdet.DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.0005
# widen_factor = 0.5
# work_dir = './work_dirs/ai537_yolov8_config'
#
# 06/09 16:53:55 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/09 16:53:55 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/albumentations/core/composition.py:144: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/09 16:53:56 - mmengine - INFO - Optimizer groups: 63 .bias, 63 conv.weight, 57 other
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 2 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmyolo/v0/yolov8/yolov8_s_syncbn_fast_8xb16-500e_coco/yolov8_s_syncbn_fast_8xb16-500e_coco_20230117_180101-5aa5f0f1.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for bbox_head.head_module.cls_preds.0.2.weight: copying a param with shape torch.Size([80, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([3, 128, 1, 1]).
# size mismatch for bbox_head.head_module.cls_preds.0.2.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([3]).
# size mismatch for bbox_head.head_module.cls_preds.1.2.weight: copying a param with shape torch.Size([80, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([3, 128, 1, 1]).
# size mismatch for bbox_head.head_module.cls_preds.1.2.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([3]).
# size mismatch for bbox_head.head_module.cls_preds.2.2.weight: copying a param with shape torch.Size([80, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([3, 128, 1, 1]).
# size mismatch for bbox_head.head_module.cls_preds.2.2.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([3]).
# The model and loaded state dict do not match exactly
#
# size mismatch for bbox_head.head_module.cls_preds.0.2.weight: copying a param with shape torch.Size([80, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([3, 128, 1, 1]).
# size mismatch for bbox_head.head_module.cls_preds.0.2.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([3]).
# size mismatch for bbox_head.head_module.cls_preds.1.2.weight: copying a param with shape torch.Size([80, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([3, 128, 1, 1]).
# size mismatch for bbox_head.head_module.cls_preds.1.2.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([3]).
# size mismatch for bbox_head.head_module.cls_preds.2.2.weight: copying a param with shape torch.Size([80, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([3, 128, 1, 1]).
# size mismatch for bbox_head.head_module.cls_preds.2.2.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([3]).
# 06/09 16:53:57 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmyolo/v0/yolov8/yolov8_s_syncbn_fast_8xb16-500e_coco/yolov8_s_syncbn_fast_8xb16-500e_coco_20230117_180101-5aa5f0f1.pth
# 06/09 16:53:57 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/09 16:53:57 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/09 16:53:57 - mmengine - INFO - Checkpoints will be saved to /nfs/hpc/share/nguypham/AI537_A3/mmyolo_AI537_2024Spring/mmyolo_AI537_2024Spring/work_dirs/ai537_yolov8_config.
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/torch/nn/modules/conv.py:459: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 06/09 16:54:01 - mmengine - INFO - Epoch(train)   [1][ 5/55]  base_lr: 1.0000e-02 lr: 2.4242e-04  eta: 1:05:50  time: 0.7190  data_time: 0.3226  memory: 3064  grad_norm: 110.9927  loss: 24.0564  loss_cls: 7.1708  loss_bbox: 9.1946  loss_dfl: 7.6910
# 06/09 16:54:02 - mmengine - INFO - Epoch(train)   [1][10/55]  base_lr: 1.0000e-02 lr: 5.4545e-04  eta: 0:43:09  time: 0.4716  data_time: 0.2410  memory: 1363  grad_norm: 130.2508  loss: 23.7501  loss_cls: 6.9444  loss_bbox: 9.0156  loss_dfl: 7.7901
# 06/09 16:54:03 - mmengine - INFO - Epoch(train)   [1][15/55]  base_lr: 1.0000e-02 lr: 8.4848e-04  eta: 0:36:34  time: 0.4002  data_time: 0.2214  memory: 1349  grad_norm: 132.9622  loss: 22.4554  loss_cls: 6.1933  loss_bbox: 8.5872  loss_dfl: 7.6749
# 06/09 16:54:04 - mmengine - INFO - Epoch(train)   [1][20/55]  base_lr: 1.0000e-02 lr: 1.1515e-03  eta: 0:32:28  time: 0.3555  data_time: 0.2044  memory: 1390  grad_norm: 128.9863  loss: 21.9524  loss_cls: 5.5881  loss_bbox: 8.7072  loss_dfl: 7.6570
# 06/09 16:54:06 - mmengine - INFO - Epoch(train)   [1][25/55]  base_lr: 1.0000e-02 lr: 1.4545e-03  eta: 0:30:28  time: 0.3340  data_time: 0.2002  memory: 1356  grad_norm: 129.6459  loss: 21.1788  loss_cls: 5.1748  loss_bbox: 8.4359  loss_dfl: 7.5681
# 06/09 16:54:07 - mmengine - INFO - Epoch(train)   [1][30/55]  base_lr: 1.0000e-02 lr: 1.7576e-03  eta: 0:28:48  time: 0.3159  data_time: 0.1918  memory: 1356  grad_norm: 127.9538  loss: 20.7871  loss_cls: 4.8022  loss_bbox: 8.4019  loss_dfl: 7.5830
# 06/09 16:54:08 - mmengine - INFO - Epoch(train)   [1][35/55]  base_lr: 1.0000e-02 lr: 2.0606e-03  eta: 0:27:24  time: 0.3009  data_time: 0.1853  memory: 1409  grad_norm: 124.1334  loss: 20.5427  loss_cls: 4.5777  loss_bbox: 8.3855  loss_dfl: 7.5794
# 06/09 16:54:09 - mmengine - INFO - Epoch(train)   [1][40/55]  base_lr: 1.0000e-02 lr: 2.3636e-03  eta: 0:26:23  time: 0.2900  data_time: 0.1797  memory: 1363  grad_norm: 121.4586  loss: 20.0161  loss_cls: 4.3216  loss_bbox: 8.1724  loss_dfl: 7.5221
# 06/09 16:54:10 - mmengine - INFO - Epoch(train)   [1][45/55]  base_lr: 1.0000e-02 lr: 2.6667e-03  eta: 0:25:33  time: 0.2811  data_time: 0.1754  memory: 1409  grad_norm: 118.9635  loss: 19.7046  loss_cls: 4.1347  loss_bbox: 8.0800  loss_dfl: 7.4899
# 06/09 16:54:11 - mmengine - INFO - Epoch(train)   [1][50/55]  base_lr: 1.0000e-02 lr: 2.9697e-03  eta: 0:24:51  time: 0.2736  data_time: 0.1719  memory: 1369  grad_norm: 117.2536  loss: 19.4795  loss_cls: 3.9933  loss_bbox: 8.0239  loss_dfl: 7.4623
# 06/09 16:54:13 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 16:54:13 - mmengine - INFO - Epoch(train)   [1][55/55]  base_lr: 1.0000e-02 lr: 3.2727e-03  eta: 0:25:38  time: 0.2389  data_time: 0.1534  memory: 2892  grad_norm: 114.7367  loss: 18.5382  loss_cls: 3.4863  loss_bbox: 7.7097  loss_dfl: 7.3422
# 06/09 16:54:14 - mmengine - INFO - Epoch(train)   [2][ 5/55]  base_lr: 1.0000e-02 lr: 3.5404e-03  eta: 0:25:08  time: 0.2384  data_time: 0.1525  memory: 1335  grad_norm: 109.9193  loss: 17.7833  loss_cls: 3.0423  loss_bbox: 7.4712  loss_dfl: 7.2698
# 06/09 16:54:15 - mmengine - INFO - Epoch(train)   [2][10/55]  base_lr: 1.0000e-02 lr: 3.8404e-03  eta: 0:24:34  time: 0.2326  data_time: 0.1479  memory: 1335  grad_norm: 105.6878  loss: 17.3942  loss_cls: 2.7697  loss_bbox: 7.3681  loss_dfl: 7.2564
# 06/09 16:54:16 - mmengine - INFO - Epoch(train)   [2][15/55]  base_lr: 1.0000e-02 lr: 4.1404e-03  eta: 0:24:11  time: 0.2320  data_time: 0.1473  memory: 1341  grad_norm: 103.8153  loss: 16.9616  loss_cls: 2.6386  loss_bbox: 7.1298  loss_dfl: 7.1932
# 06/09 16:54:17 - mmengine - INFO - Epoch(train)   [2][20/55]  base_lr: 1.0000e-02 lr: 4.4404e-03  eta: 0:23:46  time: 0.2275  data_time: 0.1429  memory: 1395  grad_norm: 98.8378  loss: 16.8650  loss_cls: 2.5203  loss_bbox: 7.1607  loss_dfl: 7.1839
# 06/09 16:54:18 - mmengine - INFO - Epoch(train)   [2][25/55]  base_lr: 1.0000e-02 lr: 4.7405e-03  eta: 0:23:33  time: 0.2278  data_time: 0.1446  memory: 1348  grad_norm: 95.2376  loss: 16.7316  loss_cls: 2.4460  loss_bbox: 7.1347  loss_dfl: 7.1508
# 06/09 16:54:19 - mmengine - INFO - Epoch(train)   [2][30/55]  base_lr: 1.0000e-02 lr: 5.0405e-03  eta: 0:23:15  time: 0.2275  data_time: 0.1435  memory: 1348  grad_norm: 94.2617  loss: 16.4870  loss_cls: 2.3495  loss_bbox: 7.0222  loss_dfl: 7.1153
# 06/09 16:54:20 - mmengine - INFO - Epoch(train)   [2][35/55]  base_lr: 1.0000e-02 lr: 5.3405e-03  eta: 0:22:59  time: 0.2271  data_time: 0.1427  memory: 1381  grad_norm: 92.3011  loss: 16.4259  loss_cls: 2.3021  loss_bbox: 7.0457  loss_dfl: 7.0781
# 06/09 16:54:21 - mmengine - INFO - Epoch(train)   [2][40/55]  base_lr: 1.0000e-02 lr: 5.6406e-03  eta: 0:22:45  time: 0.2271  data_time: 0.1426  memory: 1409  grad_norm: 90.8887  loss: 16.3727  loss_cls: 2.2480  loss_bbox: 7.0885  loss_dfl: 7.0362
# 06/09 16:54:22 - mmengine - INFO - Epoch(train)   [2][45/55]  base_lr: 1.0000e-02 lr: 5.9406e-03  eta: 0:22:31  time: 0.2268  data_time: 0.1427  memory: 1401  grad_norm: 90.1656  loss: 16.4045  loss_cls: 2.2158  loss_bbox: 7.1508  loss_dfl: 7.0378
# 06/09 16:54:23 - mmengine - INFO - Epoch(train)   [2][50/55]  base_lr: 1.0000e-02 lr: 6.2406e-03  eta: 0:22:17  time: 0.2099  data_time: 0.1433  memory: 1401  grad_norm: 89.0977  loss: 16.6134  loss_cls: 2.2138  loss_bbox: 7.3000  loss_dfl: 7.0996
# 06/09 16:54:24 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 16:54:24 - mmengine - INFO - Epoch(train)   [2][55/55]  base_lr: 1.0000e-02 lr: 6.5407e-03  eta: 0:22:03  time: 0.2075  data_time: 0.1414  memory: 1348  grad_norm: 87.1227  loss: 16.6377  loss_cls: 2.1925  loss_bbox: 7.3856  loss_dfl: 7.0596
# 06/09 16:54:25 - mmengine - INFO - Epoch(train)   [3][ 5/55]  base_lr: 1.0000e-02 lr: 6.7723e-03  eta: 0:21:54  time: 0.2089  data_time: 0.1423  memory: 1395  grad_norm: 85.5815  loss: 16.6868  loss_cls: 2.2152  loss_bbox: 7.4481  loss_dfl: 7.0235
# 06/09 16:54:26 - mmengine - INFO - Epoch(train)   [3][10/55]  base_lr: 1.0000e-02 lr: 7.0693e-03  eta: 0:21:46  time: 0.2086  data_time: 0.1415  memory: 1381  grad_norm: 83.7975  loss: 16.8857  loss_cls: 2.2185  loss_bbox: 7.6146  loss_dfl: 7.0527
# 06/09 16:54:27 - mmengine - INFO - Epoch(train)   [3][15/55]  base_lr: 1.0000e-02 lr: 7.3664e-03  eta: 0:21:36  time: 0.2083  data_time: 0.1407  memory: 1461  grad_norm: 84.1791  loss: 17.0258  loss_cls: 2.2385  loss_bbox: 7.6877  loss_dfl: 7.0996
# 06/09 16:54:29 - mmengine - INFO - Epoch(train)   [3][20/55]  base_lr: 1.0000e-02 lr: 7.6634e-03  eta: 0:21:28  time: 0.2062  data_time: 0.1365  memory: 1355  grad_norm: 84.2695  loss: 17.0589  loss_cls: 2.2608  loss_bbox: 7.6851  loss_dfl: 7.1131
# 06/09 16:54:30 - mmengine - INFO - Epoch(train)   [3][25/55]  base_lr: 1.0000e-02 lr: 7.9604e-03  eta: 0:21:19  time: 0.2056  data_time: 0.1364  memory: 1335  grad_norm: 82.5104  loss: 17.1971  loss_cls: 2.2436  loss_bbox: 7.7938  loss_dfl: 7.1597
# 06/09 16:54:31 - mmengine - INFO - Epoch(train)   [3][30/55]  base_lr: 1.0000e-02 lr: 8.2574e-03  eta: 0:21:13  time: 0.2062  data_time: 0.1368  memory: 1515  grad_norm: 82.3732  loss: 17.4904  loss_cls: 2.2646  loss_bbox: 7.9880  loss_dfl: 7.2379
# 06/09 16:54:32 - mmengine - INFO - Epoch(train)   [3][35/55]  base_lr: 1.0000e-02 lr: 8.5545e-03  eta: 0:21:05  time: 0.2055  data_time: 0.1361  memory: 1368  grad_norm: 82.0586  loss: 17.8120  loss_cls: 2.2717  loss_bbox: 8.1700  loss_dfl: 7.3703
# 06/09 16:54:33 - mmengine - INFO - Epoch(train)   [3][40/55]  base_lr: 1.0000e-02 lr: 8.8515e-03  eta: 0:21:00  time: 0.2061  data_time: 0.1362  memory: 1388  grad_norm: 80.1324  loss: 17.9986  loss_cls: 2.2503  loss_bbox: 8.2996  loss_dfl: 7.4486
# 06/09 16:54:34 - mmengine - INFO - Epoch(train)   [3][45/55]  base_lr: 1.0000e-02 lr: 9.1485e-03  eta: 0:20:52  time: 0.2060  data_time: 0.1350  memory: 1335  grad_norm: 80.1749  loss: 18.2853  loss_cls: 2.2827  loss_bbox: 8.4580  loss_dfl: 7.5446
# 06/09 16:54:35 - mmengine - INFO - Epoch(train)   [3][50/55]  base_lr: 1.0000e-02 lr: 9.4456e-03  eta: 0:20:47  time: 0.2076  data_time: 0.1359  memory: 1441  grad_norm: 79.2541  loss: 18.8088  loss_cls: 2.3361  loss_bbox: 8.7716  loss_dfl: 7.7012
# 06/09 16:54:36 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 16:54:36 - mmengine - INFO - Epoch(train)   [3][55/55]  base_lr: 1.0000e-02 lr: 9.7426e-03  eta: 0:20:40  time: 0.2055  data_time: 0.1347  memory: 1401  grad_norm: 77.8858  loss: 19.0428  loss_cls: 2.3434  loss_bbox: 8.9449  loss_dfl: 7.7545
# 06/09 16:54:37 - mmengine - INFO - Epoch(train)   [4][ 5/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:35  time: 0.2052  data_time: 0.1345  memory: 1335  grad_norm: 76.7519  loss: 19.2313  loss_cls: 2.3402  loss_bbox: 9.0434  loss_dfl: 7.8477
# 06/09 16:54:38 - mmengine - INFO - Epoch(train)   [4][10/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:28  time: 0.2049  data_time: 0.1350  memory: 1361  grad_norm: 74.6801  loss: 19.4100  loss_cls: 2.3310  loss_bbox: 9.1735  loss_dfl: 7.9055
# 06/09 16:54:39 - mmengine - INFO - Epoch(train)   [4][15/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:25  time: 0.2056  data_time: 0.1364  memory: 1355  grad_norm: 72.4948  loss: 19.7614  loss_cls: 2.3386  loss_bbox: 9.3924  loss_dfl: 8.0303
# 06/09 16:54:40 - mmengine - INFO - Epoch(train)   [4][20/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:20  time: 0.2061  data_time: 0.1372  memory: 1368  grad_norm: 70.6805  loss: 20.0900  loss_cls: 2.3939  loss_bbox: 9.5842  loss_dfl: 8.1119
# 06/09 16:54:41 - mmengine - INFO - Epoch(train)   [4][25/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:15  time: 0.2045  data_time: 0.1373  memory: 1335  grad_norm: 68.2793  loss: 20.3396  loss_cls: 2.4029  loss_bbox: 9.6926  loss_dfl: 8.2441
# 06/09 16:54:42 - mmengine - INFO - Epoch(train)   [4][30/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:12  time: 0.2058  data_time: 0.1381  memory: 1475  grad_norm: 65.3667  loss: 20.4780  loss_cls: 2.4340  loss_bbox: 9.7880  loss_dfl: 8.2560
# 06/09 16:54:43 - mmengine - INFO - Epoch(train)   [4][35/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:07  time: 0.2046  data_time: 0.1370  memory: 1355  grad_norm: 62.9814  loss: 20.6071  loss_cls: 2.4786  loss_bbox: 9.8382  loss_dfl: 8.2903
# 06/09 16:54:44 - mmengine - INFO - Epoch(train)   [4][40/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:04  time: 0.2058  data_time: 0.1381  memory: 1368  grad_norm: 60.8832  loss: 20.8914  loss_cls: 2.4924  loss_bbox: 10.0094  loss_dfl: 8.3896
# 06/09 16:54:45 - mmengine - INFO - Epoch(train)   [4][45/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:20:00  time: 0.2050  data_time: 0.1371  memory: 1335  grad_norm: 58.7273  loss: 20.8992  loss_cls: 2.4825  loss_bbox: 10.0002  loss_dfl: 8.4165
# 06/09 16:54:46 - mmengine - INFO - Epoch(train)   [4][50/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:19:57  time: 0.2074  data_time: 0.1384  memory: 1395  grad_norm: 56.6288  loss: 21.2739  loss_cls: 2.5230  loss_bbox: 10.2018  loss_dfl: 8.5491
# 06/09 16:54:47 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 16:54:47 - mmengine - INFO - Epoch(train)   [4][55/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:19:51  time: 0.2052  data_time: 0.1380  memory: 1388  grad_norm: 53.6909  loss: 21.2671  loss_cls: 2.5185  loss_bbox: 10.2155  loss_dfl: 8.5332
# 06/09 16:54:48 - mmengine - INFO - Epoch(train)   [5][ 5/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:19:49  time: 0.2071  data_time: 0.1392  memory: 1475  grad_norm: 51.8731  loss: 21.6005  loss_cls: 2.5303  loss_bbox: 10.4204  loss_dfl: 8.6498
# 06/09 16:54:49 - mmengine - INFO - Epoch(train)   [5][10/55]  base_lr: 1.0000e-02 lr: 9.7030e-03  eta: 0:19:45  time: 0.2055  data_time: 0.1386  memory: 1375  grad_norm: 49.6809  loss: 21.5541  loss_cls: 2.5287  loss_bbox: 10.4128  loss_dfl: 8.6126
# ...
# 06/09 17:13:01 - mmengine - INFO - Epoch(train)  [96][25/55]  base_lr: 1.0000e-02 lr: 6.9400e-04  eta: 0:00:51  time: 0.1783  data_time: 0.1076  memory: 1366  grad_norm: 17.1322  loss: 9.6656  loss_cls: 0.6507  loss_bbox: 3.4481  loss_dfl: 5.5669
# 06/09 17:13:02 - mmengine - INFO - Epoch(train)  [96][30/55]  base_lr: 1.0000e-02 lr: 6.9400e-04  eta: 0:00:50  time: 0.1724  data_time: 0.1010  memory: 1406  grad_norm: 17.4870  loss: 9.6097  loss_cls: 0.6244  loss_bbox: 3.4512  loss_dfl: 5.5341
# 06/09 17:13:03 - mmengine - INFO - Epoch(train)  [96][35/55]  base_lr: 1.0000e-02 lr: 6.9400e-04  eta: 0:00:49  time: 0.1653  data_time: 0.0939  memory: 1333  grad_norm: 18.0095  loss: 9.4890  loss_cls: 0.6046  loss_bbox: 3.3521  loss_dfl: 5.5323
# 06/09 17:13:03 - mmengine - INFO - Epoch(train)  [96][40/55]  base_lr: 1.0000e-02 lr: 6.9400e-04  eta: 0:00:48  time: 0.1587  data_time: 0.0867  memory: 1333  grad_norm: 18.5264  loss: 9.2693  loss_cls: 0.5678  loss_bbox: 3.2316  loss_dfl: 5.4698
# 06/09 17:13:04 - mmengine - INFO - Epoch(train)  [96][45/55]  base_lr: 1.0000e-02 lr: 6.9400e-04  eta: 0:00:47  time: 0.1519  data_time: 0.0790  memory: 1366  grad_norm: 19.5708  loss: 9.1272  loss_cls: 0.5376  loss_bbox: 3.1379  loss_dfl: 5.4518
# 06/09 17:13:05 - mmengine - INFO - Epoch(train)  [96][50/55]  base_lr: 1.0000e-02 lr: 6.9400e-04  eta: 0:00:46  time: 0.1463  data_time: 0.0729  memory: 1333  grad_norm: 20.1415  loss: 9.0199  loss_cls: 0.5126  loss_bbox: 3.0715  loss_dfl: 5.4357
# 06/09 17:13:05 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 17:13:05 - mmengine - INFO - Epoch(train)  [96][55/55]  base_lr: 1.0000e-02 lr: 6.9400e-04  eta: 0:00:45  time: 0.1419  data_time: 0.0683  memory: 1359  grad_norm: 19.7831  loss: 8.9155  loss_cls: 0.4989  loss_bbox: 3.0388  loss_dfl: 5.3778
# 06/09 17:13:06 - mmengine - INFO - Epoch(train)  [97][ 5/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:44  time: 0.1422  data_time: 0.0693  memory: 1406  grad_norm: 19.7076  loss: 8.9322  loss_cls: 0.4926  loss_bbox: 3.0828  loss_dfl: 5.3568
# 06/09 17:13:07 - mmengine - INFO - Epoch(train)  [97][10/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:43  time: 0.1419  data_time: 0.0690  memory: 1333  grad_norm: 19.6468  loss: 8.9537  loss_cls: 0.5102  loss_bbox: 3.0648  loss_dfl: 5.3787
# 06/09 17:13:08 - mmengine - INFO - Epoch(train)  [97][15/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:42  time: 0.1424  data_time: 0.0686  memory: 1333  grad_norm: 19.3009  loss: 8.9846  loss_cls: 0.5094  loss_bbox: 3.1024  loss_dfl: 5.3729
# 06/09 17:13:08 - mmengine - INFO - Epoch(train)  [97][20/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:41  time: 0.1428  data_time: 0.0680  memory: 1386  grad_norm: 19.6274  loss: 8.9791  loss_cls: 0.5157  loss_bbox: 3.0827  loss_dfl: 5.3808
# 06/09 17:13:09 - mmengine - INFO - Epoch(train)  [97][25/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:40  time: 0.1424  data_time: 0.0674  memory: 1333  grad_norm: 19.6884  loss: 8.8710  loss_cls: 0.5031  loss_bbox: 2.9999  loss_dfl: 5.3680
# 06/09 17:13:10 - mmengine - INFO - Epoch(train)  [97][30/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:39  time: 0.1424  data_time: 0.0669  memory: 1333  grad_norm: 20.3824  loss: 8.8706  loss_cls: 0.5130  loss_bbox: 2.9968  loss_dfl: 5.3607
# 06/09 17:13:10 - mmengine - INFO - Epoch(train)  [97][35/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:38  time: 0.1432  data_time: 0.0665  memory: 1359  grad_norm: 19.7982  loss: 8.8511  loss_cls: 0.5026  loss_bbox: 3.0013  loss_dfl: 5.3472
# 06/09 17:13:11 - mmengine - INFO - Epoch(train)  [97][40/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:37  time: 0.1426  data_time: 0.0664  memory: 1366  grad_norm: 18.9031  loss: 8.8339  loss_cls: 0.4942  loss_bbox: 3.0367  loss_dfl: 5.3030
# 06/09 17:13:12 - mmengine - INFO - Epoch(train)  [97][45/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:36  time: 0.1428  data_time: 0.0668  memory: 1366  grad_norm: 18.8415  loss: 8.9025  loss_cls: 0.4920  loss_bbox: 3.0866  loss_dfl: 5.3239
# 06/09 17:13:13 - mmengine - INFO - Epoch(train)  [97][50/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:35  time: 0.1431  data_time: 0.0670  memory: 1333  grad_norm: 18.9127  loss: 8.9576  loss_cls: 0.4914  loss_bbox: 3.0933  loss_dfl: 5.3729
# 06/09 17:13:13 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 17:13:13 - mmengine - INFO - Epoch(train)  [97][55/55]  base_lr: 1.0000e-02 lr: 5.9500e-04  eta: 0:00:34  time: 0.1407  data_time: 0.0658  memory: 1333  grad_norm: 19.2694  loss: 8.9268  loss_cls: 0.4984  loss_bbox: 3.0470  loss_dfl: 5.3814
# 06/09 17:13:14 - mmengine - INFO - Epoch(train)  [98][ 5/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:33  time: 0.1423  data_time: 0.0670  memory: 1333  grad_norm: 19.4408  loss: 8.9439  loss_cls: 0.4857  loss_bbox: 3.0775  loss_dfl: 5.3806
# 06/09 17:13:15 - mmengine - INFO - Epoch(train)  [98][10/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:31  time: 0.1412  data_time: 0.0667  memory: 1333  grad_norm: 19.3827  loss: 8.8874  loss_cls: 0.4852  loss_bbox: 3.0195  loss_dfl: 5.3827
# 06/09 17:13:15 - mmengine - INFO - Epoch(train)  [98][15/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:30  time: 0.1411  data_time: 0.0669  memory: 1333  grad_norm: 19.3560  loss: 8.8876  loss_cls: 0.4956  loss_bbox: 3.0111  loss_dfl: 5.3809
# 06/09 17:13:16 - mmengine - INFO - Epoch(train)  [98][20/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:29  time: 0.1413  data_time: 0.0672  memory: 1386  grad_norm: 19.2105  loss: 8.9002  loss_cls: 0.4921  loss_bbox: 3.0205  loss_dfl: 5.3876
# 06/09 17:13:17 - mmengine - INFO - Epoch(train)  [98][25/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:28  time: 0.1419  data_time: 0.0675  memory: 1366  grad_norm: 18.5439  loss: 8.8578  loss_cls: 0.4792  loss_bbox: 3.0089  loss_dfl: 5.3698
# 06/09 17:13:17 - mmengine - INFO - Epoch(train)  [98][30/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:27  time: 0.1412  data_time: 0.0677  memory: 1406  grad_norm: 18.6885  loss: 8.8921  loss_cls: 0.4794  loss_bbox: 3.0438  loss_dfl: 5.3689
# 06/09 17:13:18 - mmengine - INFO - Epoch(train)  [98][35/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:26  time: 0.1417  data_time: 0.0669  memory: 1339  grad_norm: 18.6449  loss: 8.8982  loss_cls: 0.4734  loss_bbox: 3.0480  loss_dfl: 5.3768
# 06/09 17:13:19 - mmengine - INFO - Epoch(train)  [98][40/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:25  time: 0.1419  data_time: 0.0661  memory: 1333  grad_norm: 18.7607  loss: 8.7797  loss_cls: 0.4688  loss_bbox: 2.9830  loss_dfl: 5.3278
# 06/09 17:13:20 - mmengine - INFO - Epoch(train)  [98][45/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:24  time: 0.1417  data_time: 0.0654  memory: 1333  grad_norm: 18.6548  loss: 8.7570  loss_cls: 0.4642  loss_bbox: 2.9706  loss_dfl: 5.3221
# 06/09 17:13:20 - mmengine - INFO - Epoch(train)  [98][50/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:23  time: 0.1433  data_time: 0.0664  memory: 1333  grad_norm: 18.8070  loss: 8.8128  loss_cls: 0.4749  loss_bbox: 2.9924  loss_dfl: 5.3455
# 06/09 17:13:21 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 17:13:21 - mmengine - INFO - Epoch(train)  [98][55/55]  base_lr: 1.0000e-02 lr: 4.9600e-04  eta: 0:00:22  time: 0.1407  data_time: 0.0646  memory: 1333  grad_norm: 18.7779  loss: 8.7834  loss_cls: 0.4821  loss_bbox: 2.9770  loss_dfl: 5.3243
# 06/09 17:13:22 - mmengine - INFO - Epoch(train)  [99][ 5/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:21  time: 0.1417  data_time: 0.0654  memory: 1333  grad_norm: 18.8757  loss: 8.8918  loss_cls: 0.4795  loss_bbox: 3.0539  loss_dfl: 5.3583
# 06/09 17:13:22 - mmengine - INFO - Epoch(train)  [99][10/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:20  time: 0.1415  data_time: 0.0654  memory: 1333  grad_norm: 19.1206  loss: 8.8413  loss_cls: 0.4588  loss_bbox: 3.0259  loss_dfl: 5.3566
# 06/09 17:13:23 - mmengine - INFO - Epoch(train)  [99][15/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:19  time: 0.1422  data_time: 0.0658  memory: 1359  grad_norm: 19.0385  loss: 8.8383  loss_cls: 0.4680  loss_bbox: 3.0250  loss_dfl: 5.3453
# 06/09 17:13:24 - mmengine - INFO - Epoch(train)  [99][20/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:18  time: 0.1421  data_time: 0.0662  memory: 1386  grad_norm: 18.8760  loss: 8.7986  loss_cls: 0.4653  loss_bbox: 3.0098  loss_dfl: 5.3235
# 06/09 17:13:25 - mmengine - INFO - Epoch(train)  [99][25/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:17  time: 0.1420  data_time: 0.0661  memory: 1333  grad_norm: 19.3462  loss: 8.8423  loss_cls: 0.4789  loss_bbox: 2.9979  loss_dfl: 5.3654
# 06/09 17:13:25 - mmengine - INFO - Epoch(train)  [99][30/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:16  time: 0.1422  data_time: 0.0674  memory: 1406  grad_norm: 19.3501  loss: 8.8028  loss_cls: 0.4804  loss_bbox: 2.9733  loss_dfl: 5.3492
# 06/09 17:13:26 - mmengine - INFO - Epoch(train)  [99][35/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:15  time: 0.1420  data_time: 0.0679  memory: 1359  grad_norm: 19.5754  loss: 8.9709  loss_cls: 0.4898  loss_bbox: 3.0488  loss_dfl: 5.4323
# 06/09 17:13:27 - mmengine - INFO - Epoch(train)  [99][40/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:14  time: 0.1423  data_time: 0.0688  memory: 1366  grad_norm: 19.4887  loss: 8.9104  loss_cls: 0.4874  loss_bbox: 3.0279  loss_dfl: 5.3951
# 06/09 17:13:27 - mmengine - INFO - Epoch(train)  [99][45/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:13  time: 0.1418  data_time: 0.0682  memory: 1333  grad_norm: 18.9614  loss: 8.7652  loss_cls: 0.4660  loss_bbox: 2.9495  loss_dfl: 5.3496
# 06/09 17:13:28 - mmengine - INFO - Epoch(train)  [99][50/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:12  time: 0.1439  data_time: 0.0695  memory: 1333  grad_norm: 19.2395  loss: 8.9404  loss_cls: 0.4797  loss_bbox: 3.0272  loss_dfl: 5.4335
# 06/09 17:13:29 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 17:13:29 - mmengine - INFO - Epoch(train)  [99][55/55]  base_lr: 1.0000e-02 lr: 3.9700e-04  eta: 0:00:11  time: 0.1425  data_time: 0.0686  memory: 1346  grad_norm: 20.0248  loss: 8.9823  loss_cls: 0.5016  loss_bbox: 3.0533  loss_dfl: 5.4274
# 06/09 17:13:30 - mmengine - INFO - Epoch(train) [100][ 5/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:10  time: 0.1436  data_time: 0.0694  memory: 1333  grad_norm: 19.6838  loss: 9.0232  loss_cls: 0.4977  loss_bbox: 3.1107  loss_dfl: 5.4147
# 06/09 17:13:30 - mmengine - INFO - Epoch(train) [100][10/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:09  time: 0.1430  data_time: 0.0687  memory: 1346  grad_norm: 19.5668  loss: 8.9552  loss_cls: 0.4819  loss_bbox: 3.0764  loss_dfl: 5.3968
# 06/09 17:13:31 - mmengine - INFO - Epoch(train) [100][15/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:08  time: 0.1425  data_time: 0.0695  memory: 1333  grad_norm: 19.7335  loss: 9.0016  loss_cls: 0.4825  loss_bbox: 3.1012  loss_dfl: 5.4179
# 06/09 17:13:32 - mmengine - INFO - Epoch(train) [100][20/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:07  time: 0.1431  data_time: 0.0695  memory: 1333  grad_norm: 20.0300  loss: 8.9894  loss_cls: 0.4846  loss_bbox: 3.0900  loss_dfl: 5.4148
# 06/09 17:13:32 - mmengine - INFO - Epoch(train) [100][25/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:06  time: 0.1428  data_time: 0.0684  memory: 1333  grad_norm: 20.1386  loss: 8.9219  loss_cls: 0.4794  loss_bbox: 3.0288  loss_dfl: 5.4137
# 06/09 17:13:33 - mmengine - INFO - Epoch(train) [100][30/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:05  time: 0.1429  data_time: 0.0681  memory: 1333  grad_norm: 20.0785  loss: 8.8434  loss_cls: 0.4796  loss_bbox: 2.9867  loss_dfl: 5.3771
# 06/09 17:13:34 - mmengine - INFO - Epoch(train) [100][35/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:04  time: 0.1425  data_time: 0.0671  memory: 1406  grad_norm: 20.4514  loss: 8.9198  loss_cls: 0.4892  loss_bbox: 3.0262  loss_dfl: 5.4044
# 06/09 17:13:35 - mmengine - INFO - Epoch(train) [100][40/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:03  time: 0.1441  data_time: 0.0676  memory: 1366  grad_norm: 20.1993  loss: 8.9790  loss_cls: 0.4861  loss_bbox: 3.0885  loss_dfl: 5.4044
# 06/09 17:13:35 - mmengine - INFO - Epoch(train) [100][45/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:02  time: 0.1442  data_time: 0.0684  memory: 1333  grad_norm: 20.1196  loss: 8.8901  loss_cls: 0.4767  loss_bbox: 3.0577  loss_dfl: 5.3557
# 06/09 17:13:36 - mmengine - INFO - Epoch(train) [100][50/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:01  time: 0.1453  data_time: 0.0688  memory: 1366  grad_norm: 19.2542  loss: 8.7856  loss_cls: 0.4678  loss_bbox: 2.9718  loss_dfl: 5.3460
# 06/09 17:13:37 - mmengine - INFO - Exp name: ai537_yolov8_config_20240609_165352
# 06/09 17:13:37 - mmengine - INFO - Epoch(train) [100][55/55]  base_lr: 1.0000e-02 lr: 2.9800e-04  eta: 0:00:00  time: 0.1438  data_time: 0.0682  memory: 1386  grad_norm: 19.2097  loss: 8.7196  loss_cls: 0.4631  loss_bbox: 2.9450  loss_dfl: 5.3115
# 06/09 17:13:37 - mmengine - INFO - Saving checkpoint at 100 epochs
# 06/09 17:13:38 - mmengine - INFO - Epoch(val) [100][ 5/51]    eta: 0:00:01  time: 0.0171  data_time: 0.0011  memory: 274
# 06/09 17:13:38 - mmengine - INFO - Epoch(val) [100][10/51]    eta: 0:00:00  time: 0.0171  data_time: 0.0011  memory: 274
# 06/09 17:13:38 - mmengine - INFO - Epoch(val) [100][15/51]    eta: 0:00:00  time: 0.0172  data_time: 0.0011  memory: 274
# 06/09 17:13:38 - mmengine - INFO - Epoch(val) [100][20/51]    eta: 0:00:00  time: 0.0172  data_time: 0.0011  memory: 274
# 06/09 17:13:39 - mmengine - INFO - Epoch(val) [100][25/51]    eta: 0:00:00  time: 0.0173  data_time: 0.0011  memory: 274
# 06/09 17:13:39 - mmengine - INFO - Epoch(val) [100][30/51]    eta: 0:00:00  time: 0.0173  data_time: 0.0011  memory: 274
# 06/09 17:13:39 - mmengine - INFO - Epoch(val) [100][35/51]    eta: 0:00:00  time: 0.0173  data_time: 0.0011  memory: 274
# 06/09 17:13:39 - mmengine - INFO - Epoch(val) [100][40/51]    eta: 0:00:00  time: 0.0173  data_time: 0.0011  memory: 274
# 06/09 17:13:39 - mmengine - INFO - Epoch(val) [100][45/51]    eta: 0:00:00  time: 0.0174  data_time: 0.0011  memory: 274
# 06/09 17:13:39 - mmengine - INFO - Epoch(val) [100][50/51]    eta: 0:00:00  time: 0.0175  data_time: 0.0011  memory: 274
# 06/09 17:13:39 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.25s).
# Accumulating evaluation results...
# DONE (t=0.07s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.660
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.859
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.728
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.259
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.617
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.418
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.784
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.703
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.830
# 06/09 17:13:40 - mmengine - INFO - bbox_mAP_copypaste: 0.660 0.859 0.728 0.259 0.617 0.712
# 06/09 17:13:40 - mmengine - INFO - Epoch(val) [100][51/51]    coco/bbox_mAP: 0.6600  coco/bbox_mAP_50: 0.8590  coco/bbox_mAP_75: 0.7280  coco/bbox_mAP_s: 0.2590  coco/bbox_mAP_m: 0.6170  coco/bbox_mAP_l: 0.7120  data_time: 0.0011  time: 0.0173

# %% [markdown]
# ### Saved outputs
# Upon running the above training command, a `work_dirs/ai537_yolov8_config/` directory will be automatically generated:
#
# <div align=center>
# <img src="example_imgs/training_directory.png" alt="image"/>
# </div>
#
# In this directory, the model weights checkpoint file (e.g., epoch_20.pth) and the training config file (e.g., ai537_yolov8_config.py) for the most recent run will be saved. __After a run, you will most likely want to rename these two files as they will be overwritten the next time you run the train command.__
#
# ### Additional Note
# Some warning messages may appear during training. These are not errors and will not impact the performance of your model. Any actual errors should result in your model not training from the start.

# %% [markdown]
# ### Resume training after an iterruption
#
# If you stop training, you can add `--resume` to the end of the training command and the program will automatically resume training with the latest weights file from `work_dirs`.

# %%
# !python tools/train.py configs/yolov8/ai537_yolov8_config.py --resume
# Out:
# 06/09 17:14:00 - mmengine - WARNING - Failed to search registry with scope "mmyolo" in the "log_processor" registry tree. As a workaround, the current "log_processor" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmyolo" is a correct scope, or whether the registry is initialized.
# 06/09 17:14:01 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.19 (default, Mar 20 2024, 19:58:24) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 147974559
#     GPU 0: NVIDIA A40
#     CUDA_HOME: None
#     GCC: gcc (GCC) 11.4.1 20230605 (Red Hat 11.4.1-2)
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.9.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 147974559
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/09 17:14:02 - mmengine - INFO - Config:
# _backend_args = None
# _multiscale_resize_transforms = [
#     dict(
#         transforms=[
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
#     dict(
#         transforms=[
#             dict(scale=(
#                 320,
#                 320,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     320,
#                     320,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
#     dict(
#         transforms=[
#             dict(scale=(
#                 960,
#                 960,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     960,
#                     960,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
# ]
# affine_scale = 0.5
# albu_train_transforms = [
#     dict(p=0.01, type='Blur'),
#     dict(p=0.01, type='MedianBlur'),
#     dict(p=0.01, type='ToGray'),
#     dict(p=0.01, type='CLAHE'),
# ]
# backend_args = None
# base_lr = 0.01
# batch_shapes_cfg = None
# class_name = (
#     'cat',
#     'dog',
#     'monkey',
# )
# close_mosaic_epochs = 5
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0001,
#         priority=49,
#         strict_load=False,
#         type='EMAHook',
#         update_buffers=True),
#     dict(
#         switch_epoch=95,
#         switch_pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=True,
#                 pad_val=dict(img=114.0),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_aspect_ratio=100,
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='mmdet.PipelineSwitchHook'),
# ]
# data_root = './data/cat_dog_monkey_dataset/'
# dataset_type = 'YOLOv5CocoDataset'
# deepen_factor = 0.33
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=2, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=5, type='LoggerHook'),
#     param_scheduler=dict(
#         lr_factor=0.01,
#         max_epochs=100,
#         scheduler_type='linear',
#         type='YOLOv5ParamSchedulerHook',
#         warmup_mim_iter=10),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='mmdet.DetVisualizationHook'))
# default_scope = 'mmyolo'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_scale = (
#     640,
#     640,
# )
# img_scales = [
#     (
#         640,
#         640,
#     ),
#     (
#         320,
#         320,
#     ),
#     (
#         960,
#         960,
#     ),
# ]
# last_stage_out_channels = 1024
# last_transform = [
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 8.5
# loss_cls_weight = 1.0
# loss_dfl_weight = 0.275
# lr_factor = 0.01
# max_aspect_ratio = 100
# max_epochs = 100
# max_keep_ckpts = 2
# metainfo = dict(
#     classes=(
#         'cat',
#         'dog',
#         'monkey',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#         (
#             119,
#             11,
#             32,
#         ),
#         (
#             165,
#             42,
#             42,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         arch='P5',
#         deepen_factor=0.33,
#         frozen_stages=4,
#         last_stage_out_channels=1024,
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         type='YOLOv8CSPDarknet',
#         widen_factor=0.5),
#     bbox_head=dict(
#         bbox_coder=dict(type='DistancePointBBoxCoder'),
#         head_module=dict(
#             act_cfg=dict(inplace=True, type='SiLU'),
#             featmap_strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             in_channels=[
#                 256,
#                 512,
#                 1024,
#             ],
#             norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#             num_classes=3,
#             reg_max=16,
#             type='YOLOv8HeadModule',
#             widen_factor=0.5),
#         loss_bbox=dict(
#             bbox_format='xyxy',
#             iou_mode='ciou',
#             loss_weight=8.5,
#             reduction='sum',
#             return_iou=False,
#             type='IoULoss'),
#         loss_cls=dict(
#             alpha=0.25,
#             gamma=2.0,
#             loss_weight=1.0,
#             reduction='none',
#             type='mmdet.FocalLoss',
#             use_sigmoid=True),
#         loss_dfl=dict(
#             loss_weight=0.275,
#             reduction='mean',
#             type='mmdet.DistributionFocalLoss'),
#         prior_generator=dict(
#             offset=0.5, strides=[
#                 8,
#                 16,
#                 32,
#             ], type='mmdet.MlvlPointGenerator'),
#         type='YOLOv8Head'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             0.0,
#             0.0,
#             0.0,
#         ],
#         std=[
#             255.0,
#             255.0,
#             255.0,
#         ],
#         type='YOLOv5DetDataPreprocessor'),
#     neck=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         deepen_factor=0.33,
#         in_channels=[
#             256,
#             512,
#             1024,
#         ],
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         num_csp_blocks=3,
#         out_channels=[
#             256,
#             512,
#             1024,
#         ],
#         type='YOLOv8PAFPN',
#         widen_factor=0.5),
#     test_cfg=dict(
#         max_per_img=300,
#         multi_label=True,
#         nms=dict(iou_threshold=0.7, type='nms'),
#         nms_pre=30000,
#         score_thr=0.001),
#     train_cfg=dict(
#         assigner=dict(
#             alpha=0.5,
#             beta=6.0,
#             eps=1e-09,
#             num_classes=3,
#             topk=10,
#             type='BatchTaskAlignedAssigner',
#             use_ciou=True)),
#     type='YOLODetector')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.7, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# norm_cfg = dict(eps=0.001, momentum=0.03, type='BN')
# num_classes = 3
# num_det_layers = 3
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=10.0),
#     constructor='YOLOv5OptimizerConstructor',
#     optimizer=dict(
#         batch_size_per_gpu=8,
#         lr=0.01,
#         momentum=0.937,
#         nesterov=True,
#         type='SGD',
#         weight_decay=0.0005),
#     type='OptimWrapper')
# param_scheduler = None
# persistent_workers = True
# pre_transform = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
# ]
# resume = True
# save_epoch_intervals = 10
# strides = [
#     8,
#     16,
#     32,
# ]
# tal_alpha = 0.5
# tal_beta = 6.0
# tal_topk = 10
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img='val/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='YOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='./data/cat_dog_monkey_dataset/val.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(scale=(
#         640,
#         640,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=False,
#         pad_val=dict(img=114),
#         scale=(
#             640,
#             640,
#         ),
#         type='LetterResize'),
#     dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'pad_param',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_ann_file = 'annotations/instances_train2017.json'
# train_batch_size_per_gpu = 8
# train_cfg = dict(
#     dynamic_intervals=[
#         (
#             490,
#             1,
#         ),
#     ],
#     max_epochs=100,
#     type='EpochBasedTrainLoop',
#     val_interval=10)
# train_data_prefix = 'train2017/'
# train_dataloader = dict(
#     batch_size=8,
#     collate_fn=dict(type='yolov5_collate'),
#     dataset=dict(
#         ann_file='train_cat_annotation_100.json',
#         data_prefix=dict(img='train/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 img_scale=(
#                     640,
#                     640,
#                 ),
#                 pad_val=114.0,
#                 pre_transform=[
#                     dict(backend_args=None, type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                 ],
#                 type='Mosaic'),
#             dict(
#                 border=(
#                     -320,
#                     -320,
#                 ),
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_aspect_ratio=100,
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='YOLOv5CocoDataset'),
#     num_workers=1,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_num_workers = 1
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         img_scale=(
#             640,
#             640,
#         ),
#         pad_val=114.0,
#         pre_transform=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#         ],
#         type='Mosaic'),
#     dict(
#         border=(
#             -320,
#             -320,
#         ),
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_pipeline_stage2 = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(scale=(
#         640,
#         640,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=True,
#         pad_val=dict(img=114.0),
#         scale=(
#             640,
#             640,
#         ),
#         type='LetterResize'),
#     dict(
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# tta_model = dict(
#     tta_cfg=dict(max_per_img=300, nms=dict(iou_threshold=0.65, type='nms')),
#     type='mmdet.DetTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             640,
#                             640,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 640,
#                                 640,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             320,
#                             320,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 320,
#                                 320,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             960,
#                             960,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 960,
#                                 960,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#             ],
#             [
#                 dict(prob=1.0, type='mmdet.RandomFlip'),
#                 dict(prob=0.0, type='mmdet.RandomFlip'),
#             ],
#             [
#                 dict(type='mmdet.LoadAnnotations', with_bbox=True),
#             ],
#             [
#                 dict(
#                     meta_keys=(
#                         'img_id',
#                         'img_path',
#                         'ori_shape',
#                         'img_shape',
#                         'scale_factor',
#                         'pad_param',
#                         'flip',
#                         'flip_direction',
#                     ),
#                     type='mmdet.PackDetInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_ann_file = 'annotations/instances_val2017.json'
# val_batch_size_per_gpu = 1
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'val2017/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img='val/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='YOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='./data/cat_dog_monkey_dataset/val.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 2
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='mmdet.DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.0005
# widen_factor = 0.5
# work_dir = './work_dirs/ai537_yolov8_config'
#
# 06/09 17:14:03 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/09 17:14:03 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/albumentations/core/composition.py:144: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/09 17:14:04 - mmengine - INFO - Optimizer groups: 63 .bias, 63 conv.weight, 57 other
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 2 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/09 17:14:05 - mmengine - INFO - Auto resumed from the latest checkpoint /nfs/hpc/share/nguypham/AI537_A3/mmyolo_AI537_2024Spring/mmyolo_AI537_2024Spring/work_dirs/ai537_yolov8_config/epoch_100.pth.
# Loads checkpoint by local backend from path: /nfs/hpc/share/nguypham/AI537_A3/mmyolo_AI537_2024Spring/mmyolo_AI537_2024Spring/work_dirs/ai537_yolov8_config/epoch_100.pth
# 06/09 17:14:05 - mmengine - INFO - Load checkpoint from /nfs/hpc/share/nguypham/AI537_A3/mmyolo_AI537_2024Spring/mmyolo_AI537_2024Spring/work_dirs/ai537_yolov8_config/epoch_100.pth
# 06/09 17:14:05 - mmengine - WARNING - `resume_param_scheduler` is True but `self.param_schedulers` is None, so skip resuming parameter schedulers
# 06/09 17:14:05 - mmengine - INFO - resumed epoch: 100, iter: 5500
# 06/09 17:14:05 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/09 17:14:05 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/09 17:14:05 - mmengine - INFO - Checkpoints will be saved to /nfs/hpc/share/nguypham/AI537_A3/mmyolo_AI537_2024Spring/mmyolo_AI537_2024Spring/work_dirs/ai537_yolov8_config.

# %% [markdown]
# ### Training visualization
#
# MMYOLO currently supports local, TensorBoard, WandB and other back-end visualization. The default is to use local visualization, and you can switch to WandB and other real-time visualization of various indicators in the training process.
#
# For details about how to enable training visualization, please check `demo/15_minutes_object_detection.ipynb`

# %% [markdown]
# ## Testing
# To evaluate your trained model on the validation set and get per class AP metrics (AP@50 and AP@75), run the following command __(Note that $\{EPOCHNUM\}$ in this command needs to be replaced with the epoch number of your last/best training iteration)__:

# %%
# !python tools/test.py configs/yolov8/ai537_yolov8_config.py \
                      work_dirs/ai537_yolov8_config/0_fl_giou_dfl.pth \
                      --cfg-options test_evaluator.classwise=True \
                      --show-dir show_results
# Out:
# 06/09 19:20:31 - mmengine - WARNING - Failed to search registry with scope "mmyolo" in the "log_processor" registry tree. As a workaround, the current "log_processor" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmyolo" is a correct scope, or whether the registry is initialized.
# 06/09 19:20:32 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.19 (default, Mar 20 2024, 19:58:24) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 2055510622
#     GPU 0: NVIDIA A40
#     CUDA_HOME: None
#     GCC: gcc (GCC) 11.4.1 20230605 (Red Hat 11.4.1-2)
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.9.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 2055510622
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/09 19:20:33 - mmengine - INFO - Config:
# _backend_args = None
# _multiscale_resize_transforms = [
#     dict(
#         transforms=[
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
#     dict(
#         transforms=[
#             dict(scale=(
#                 320,
#                 320,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     320,
#                     320,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
#     dict(
#         transforms=[
#             dict(scale=(
#                 960,
#                 960,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     960,
#                     960,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
# ]
# affine_scale = 0.5
# albu_train_transforms = [
#     dict(p=0.01, type='Blur'),
#     dict(p=0.01, type='MedianBlur'),
#     dict(p=0.01, type='ToGray'),
#     dict(p=0.01, type='CLAHE'),
# ]
# backend_args = None
# base_lr = 0.01
# batch_shapes_cfg = None
# class_name = (
#     'cat',
#     'dog',
#     'monkey',
# )
# close_mosaic_epochs = 5
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0001,
#         priority=49,
#         strict_load=False,
#         type='EMAHook',
#         update_buffers=True),
#     dict(
#         switch_epoch=95,
#         switch_pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=True,
#                 pad_val=dict(img=114.0),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_aspect_ratio=100,
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='mmdet.PipelineSwitchHook'),
# ]
# data_root = './data/cat_dog_monkey_dataset/'
# dataset_type = 'YOLOv5CocoDataset'
# deepen_factor = 0.33
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=2, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=5, type='LoggerHook'),
#     param_scheduler=dict(
#         lr_factor=0.01,
#         max_epochs=100,
#         scheduler_type='linear',
#         type='YOLOv5ParamSchedulerHook',
#         warmup_mim_iter=10),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(
#         draw=True,
#         test_out_dir='show_results',
#         type='mmdet.DetVisualizationHook'))
# default_scope = 'mmyolo'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_scale = (
#     640,
#     640,
# )
# img_scales = [
#     (
#         640,
#         640,
#     ),
#     (
#         320,
#         320,
#     ),
#     (
#         960,
#         960,
#     ),
# ]
# last_stage_out_channels = 1024
# last_transform = [
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# launcher = 'none'
# load_from = 'work_dirs/ai537_yolov8_config/0_fl_ciou_dfl.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 8.5
# loss_cls_weight = 1.0
# loss_dfl_weight = 0.275
# lr_factor = 0.01
# max_aspect_ratio = 100
# max_epochs = 100
# max_keep_ckpts = 2
# metainfo = dict(
#     classes=(
#         'cat',
#         'dog',
#         'monkey',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#         (
#             119,
#             11,
#             32,
#         ),
#         (
#             165,
#             42,
#             42,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         arch='P5',
#         deepen_factor=0.33,
#         frozen_stages=4,
#         last_stage_out_channels=1024,
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         type='YOLOv8CSPDarknet',
#         widen_factor=0.5),
#     bbox_head=dict(
#         bbox_coder=dict(type='DistancePointBBoxCoder'),
#         head_module=dict(
#             act_cfg=dict(inplace=True, type='SiLU'),
#             featmap_strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             in_channels=[
#                 256,
#                 512,
#                 1024,
#             ],
#             norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#             num_classes=3,
#             reg_max=16,
#             type='YOLOv8HeadModule',
#             widen_factor=0.5),
#         loss_bbox=dict(
#             bbox_format='xyxy',
#             iou_mode='ciou',
#             loss_weight=8.5,
#             reduction='sum',
#             return_iou=False,
#             type='IoULoss'),
#         loss_cls=dict(
#             alpha=0.25,
#             gamma=2.0,
#             loss_weight=1.0,
#             reduction='none',
#             type='mmdet.FocalLoss',
#             use_sigmoid=True),
#         loss_dfl=dict(
#             loss_weight=0.275,
#             reduction='mean',
#             type='mmdet.DistributionFocalLoss'),
#         prior_generator=dict(
#             offset=0.5, strides=[
#                 8,
#                 16,
#                 32,
#             ], type='mmdet.MlvlPointGenerator'),
#         type='YOLOv8Head'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             0.0,
#             0.0,
#             0.0,
#         ],
#         std=[
#             255.0,
#             255.0,
#             255.0,
#         ],
#         type='YOLOv5DetDataPreprocessor'),
#     neck=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         deepen_factor=0.33,
#         in_channels=[
#             256,
#             512,
#             1024,
#         ],
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         num_csp_blocks=3,
#         out_channels=[
#             256,
#             512,
#             1024,
#         ],
#         type='YOLOv8PAFPN',
#         widen_factor=0.5),
#     test_cfg=dict(
#         max_per_img=300,
#         multi_label=True,
#         nms=dict(iou_threshold=0.7, type='nms'),
#         nms_pre=30000,
#         score_thr=0.001),
#     train_cfg=dict(
#         assigner=dict(
#             alpha=0.5,
#             beta=6.0,
#             eps=1e-09,
#             num_classes=3,
#             topk=10,
#             type='BatchTaskAlignedAssigner',
#             use_ciou=True)),
#     type='YOLODetector')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.7, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# norm_cfg = dict(eps=0.001, momentum=0.03, type='BN')
# num_classes = 3
# num_det_layers = 3
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=10.0),
#     constructor='YOLOv5OptimizerConstructor',
#     optimizer=dict(
#         batch_size_per_gpu=8,
#         lr=0.01,
#         momentum=0.937,
#         nesterov=True,
#         type='SGD',
#         weight_decay=0.0005),
#     type='OptimWrapper')
# param_scheduler = None
# persistent_workers = True
# pre_transform = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
# ]
# resume = False
# save_epoch_intervals = 10
# strides = [
#     8,
#     16,
#     32,
# ]
# tal_alpha = 0.5
# tal_beta = 6.0
# tal_topk = 10
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img='val/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='YOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='./data/cat_dog_monkey_dataset/val.json',
#     classwise=True,
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(scale=(
#         640,
#         640,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=False,
#         pad_val=dict(img=114),
#         scale=(
#             640,
#             640,
#         ),
#         type='LetterResize'),
#     dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'pad_param',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_ann_file = 'annotations/instances_train2017.json'
# train_batch_size_per_gpu = 8
# train_cfg = dict(
#     dynamic_intervals=[
#         (
#             490,
#             1,
#         ),
#     ],
#     max_epochs=100,
#     type='EpochBasedTrainLoop',
#     val_interval=10)
# train_data_prefix = 'train2017/'
# train_dataloader = dict(
#     batch_size=8,
#     collate_fn=dict(type='yolov5_collate'),
#     dataset=dict(
#         ann_file='train_cat_annotation_100.json',
#         data_prefix=dict(img='train/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 img_scale=(
#                     640,
#                     640,
#                 ),
#                 pad_val=114.0,
#                 pre_transform=[
#                     dict(backend_args=None, type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                 ],
#                 type='Mosaic'),
#             dict(
#                 border=(
#                     -320,
#                     -320,
#                 ),
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_aspect_ratio=100,
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='YOLOv5CocoDataset'),
#     num_workers=1,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_num_workers = 1
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         img_scale=(
#             640,
#             640,
#         ),
#         pad_val=114.0,
#         pre_transform=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#         ],
#         type='Mosaic'),
#     dict(
#         border=(
#             -320,
#             -320,
#         ),
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_pipeline_stage2 = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(scale=(
#         640,
#         640,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=True,
#         pad_val=dict(img=114.0),
#         scale=(
#             640,
#             640,
#         ),
#         type='LetterResize'),
#     dict(
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# tta_model = dict(
#     tta_cfg=dict(max_per_img=300, nms=dict(iou_threshold=0.65, type='nms')),
#     type='mmdet.DetTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             640,
#                             640,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 640,
#                                 640,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             320,
#                             320,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 320,
#                                 320,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             960,
#                             960,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 960,
#                                 960,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#             ],
#             [
#                 dict(prob=1.0, type='mmdet.RandomFlip'),
#                 dict(prob=0.0, type='mmdet.RandomFlip'),
#             ],
#             [
#                 dict(type='mmdet.LoadAnnotations', with_bbox=True),
#             ],
#             [
#                 dict(
#                     meta_keys=(
#                         'img_id',
#                         'img_path',
#                         'ori_shape',
#                         'img_shape',
#                         'scale_factor',
#                         'pad_param',
#                         'flip',
#                         'flip_direction',
#                     ),
#                     type='mmdet.PackDetInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_ann_file = 'annotations/instances_val2017.json'
# val_batch_size_per_gpu = 1
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'val2017/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img='val/'),
#         data_root='./data/cat_dog_monkey_dataset/',
#         metainfo=dict(
#             classes=(
#                 'cat',
#                 'dog',
#                 'monkey',
#             ),
#             palette=[
#                 (
#                     20,
#                     220,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     165,
#                     42,
#                     42,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='YOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='./data/cat_dog_monkey_dataset/val.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 2
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='mmdet.DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.0005
# widen_factor = 0.5
# work_dir = './work_dirs/ai537_yolov8_config'
#
# 06/09 19:20:34 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/09 19:20:34 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 2 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loads checkpoint by local backend from path: work_dirs/ai537_yolov8_config/0_fl_ciou_dfl.pth
# 06/09 19:20:40 - mmengine - INFO - Load checkpoint from work_dirs/ai537_yolov8_config/0_fl_ciou_dfl.pth
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 2 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/torch/nn/modules/conv.py:459: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
# /nfs/hpc/share/nguypham/miniconda3/envs/myenv_hw3/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#   warnings.warn(
# 06/09 19:20:42 - mmengine - INFO - Epoch(test) [ 5/51]    eta: 0:00:17  time: 0.3742  data_time: 0.2487  memory: 654
# 06/09 19:20:42 - mmengine - INFO - Epoch(test) [10/51]    eta: 0:00:10  time: 0.2495  data_time: 0.1771  memory: 241
# 06/09 19:20:43 - mmengine - INFO - Epoch(test) [15/51]    eta: 0:00:07  time: 0.2053  data_time: 0.1512  memory: 241
# 06/09 19:20:44 - mmengine - INFO - Epoch(test) [20/51]    eta: 0:00:05  time: 0.1854  data_time: 0.1405  memory: 241
# 06/09 19:20:44 - mmengine - INFO - Epoch(test) [25/51]    eta: 0:00:04  time: 0.1701  data_time: 0.1306  memory: 241
# 06/09 19:20:45 - mmengine - INFO - Epoch(test) [30/51]    eta: 0:00:03  time: 0.1595  data_time: 0.1237  memory: 241
# 06/09 19:20:45 - mmengine - INFO - Epoch(test) [35/51]    eta: 0:00:02  time: 0.1526  data_time: 0.1196  memory: 241
# 06/09 19:20:46 - mmengine - INFO - Epoch(test) [40/51]    eta: 0:00:01  time: 0.1463  data_time: 0.1151  memory: 241
# 06/09 19:20:46 - mmengine - INFO - Epoch(test) [45/51]    eta: 0:00:00  time: 0.1418  data_time: 0.1121  memory: 241
# 06/09 19:20:47 - mmengine - INFO - Epoch(test) [50/51]    eta: 0:00:00  time: 0.1382  data_time: 0.1100  memory: 241
# 06/09 19:20:47 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.14s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.18s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.452
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.458
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.257
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.589
# 06/09 19:20:48 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | cat      | 0.0   | 0.0    | 0.0    | nan   | 0.0   | 0.003 |
# | dog      | 0.645 | 0.873  | 0.704  | nan   | 0.743 | 0.62  |
# | monkey   | 0.635 | 0.844  | 0.705  | 0.102 | 0.612 | 0.749 |
# +----------+-------+--------+--------+-------+-------+-------+
# 06/09 19:20:48 - mmengine - INFO - bbox_mAP_copypaste: 0.427 0.572 0.470 0.102 0.452 0.458
# 06/09 19:20:48 - mmengine - INFO - Epoch(test) [51/51]    coco/cat_precision: 0.0000  coco/dog_precision: 0.6450  coco/monkey_precision: 0.6350  coco/bbox_mAP: 0.4270  coco/bbox_mAP_50: 0.5720  coco/bbox_mAP_75: 0.4700  coco/bbox_mAP_s: 0.1020  coco/bbox_mAP_m: 0.4520  coco/bbox_mAP_l: 0.4580  data_time: 0.1095  time: 0.1373

# %% [markdown]
# Running the above test command should print out per class average precision (AP) metrics that looks something like:
# ```text
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | cat      | 0.572 | 0.785  | 0.571  | nan   | 0.438 | 0.6   |
# | dog      | 0.666 | 0.858  | 0.804  | nan   | 0.708 | 0.661 |
# | monkey   | 0.663 | 0.867  | 0.699  | 0.21  | 0.61  | 0.779 |
# +----------+-------+--------+--------+-------+-------+-------+
# ```
#
# In addition to AP metrics, result images will be automatically saved to the ```work_dirs/ai537_yolov8_config/{TIMESTAMP}/show_results``` directory. Below is one of the result images where the left image is the ground truth annotation and the right image is the predicted annotation by the model.
#
# <div align=center>
# <img src="example_imgs/cats_and_monkeys_000.jpg" alt="result_img"/>
# </div>
